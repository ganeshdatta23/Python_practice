# %%
fruits = ["mango",'orange',"cherry"]
for i in fruits:
    print(i,"--->",i[::-1])
# Out:
# mango ---> ognam
# orange ---> egnaro
# cherry ---> yrrehc

# %%
for i in "Prajwal":
    # print(i)
    if i == 'w':
        break
    print(i)
# Out:
# P
# r
# a
# j

# %%
a="prajwal"
# print(a[2])
for i in a:
    print(i)
    if i=='a' and a.index(i)!=2:
        break

# for i in a:
    # print()
    # if i == a[2]:
    #     pass
    # print(i)
   
# print(a[-2])
# Out:
# p
# r
# a
# j
# w
# a
# l

# %%
a= "prajwal" 
for i in range(len(a)):
    print(a[i])
    if i==5:
        break
# Out:
# p
# r
# a
# j
# w
# a

# %%
name ="mahesh babu"
print(len(name))
for i in range(len(name)):
    print(i,"--->",name[i])
    if i==5:
        break
# Out:
# 11
# 0 ---> m
# 1 ---> a
# 2 ---> h
# 3 ---> e
# 4 ---> s
# 5 ---> h

# %%
# for i in range(5):
#     print(i)
# else:
#     print("its done")

a={1:'apple',1:"hamster"}
a
# Out:
# {1: 'hamster'}

# %%
a="mahesh babu" 
counter = {} #empty dict
for i in a:
    if i in counter:
        counter[i]+=1
    else:
        counter[i]=1

duplicate=0
for j in counter.values():
    if j>1:
        duplicate+=1
print(counter) #counter save kv pairs
print(duplicate) #save total dup count
for i,j in counter.items():
    if j>1:
        print(i,"===>",j,"times")
# Out:
# {'m': 1, 'a': 2, 'h': 2, 'e': 1, 's': 1, ' ': 1, 'b': 2, 'u': 1}
# 3
# a ===> 2 times
# h ===> 2 times
# b ===> 2 times

# %% [markdown]
# The enumerate function adds a counter to an iterable and returns it in a form of an enumerate object. This object can be used directly in for loops. In this example, the for loop is used with enumerate on a list ['a', 'b', 'c'].

# %%
l1 = ["one",'two','three']
for i,j in enumerate(l1):
    print(i,j)
# Out:
# 0 one
# 1 two
# 2 three

# %%
pip install pytest requests pytest-html
# Out:
# Collecting pytest
#   Downloading pytest-9.0.2-py3-none-any.whl.metadata (7.6 kB)
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting pytest-html
#   Downloading pytest_html-4.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting iniconfig>=1.0.1 (from pytest)
#   Downloading iniconfig-2.3.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging>=22 in /home/ganesh-datta-padamata/prac/Python_practice/.venv/lib/python3.12/site-packages (from pytest) (26.0)
# Collecting pluggy<2,>=1.5 (from pytest)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pygments>=2.7.2 in /home/ganesh-datta-padamata/prac/Python_practice/.venv/lib/python3.12/site-packages (from pytest) (2.19.2)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting jinja2>=3 (from pytest-html)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting pytest-metadata>=2 (from pytest-html)
#   Downloading pytest_metadata-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=3->pytest-html)
#   Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading pytest-9.0.2-py3-none-any.whl (374 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (207 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading pytest_html-4.2.0-py3-none-any.whl (23 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading iniconfig-2.3.0-py3-none-any.whl (7.5 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading pytest_metadata-3.1.1-py3-none-any.whl (11 kB)
# Installing collected packages: urllib3, pluggy, MarkupSafe, iniconfig, idna, charset_normalizer, certifi, requests, pytest, jinja2, pytest-metadata, pytest-html
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [pytest-html]m  9/12 [jinja2]pytest]_normalizer]
# Successfully installed MarkupSafe-3.0.3 certifi-2026.2.25 charset_normalizer-3.4.6 idna-3.11 iniconfig-2.3.0 jinja2-3.1.6 pluggy-1.6.0 pytest-9.0.2 pytest-html-4.2.0 pytest-metadata-3.1.1 requests-2.32.5 urllib3-2.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

def test_get_users():
    url = "https://jsonplaceholder.typicode.com/users"
    response = requests.get(url)

    assert response.status_code == 200
    assert isinstance(response.json(), list)

# %%
pip install allure-pytest
# Out:
# Collecting allure-pytest
#   Downloading allure_pytest-2.15.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pytest>=4.5.0 in /home/ganesh-datta-padamata/prac/Python_practice/.venv/lib/python3.12/site-packages (from allure-pytest) (9.0.2)
# Collecting allure-python-commons==2.15.3 (from allure-pytest)
#   Downloading allure_python_commons-2.15.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting attrs>=16.0.0 (from allure-python-commons==2.15.3->allure-pytest)
#   Downloading attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: pluggy>=0.4.0 in /home/ganesh-datta-padamata/prac/Python_practice/.venv/lib/python3.12/site-packages (from allure-python-commons==2.15.3->allure-pytest) (1.6.0)
# Requirement already satisfied: iniconfig>=1.0.1 in /home/ganesh-datta-padamata/prac/Python_practice/.venv/lib/python3.12/site-packages (from pytest>=4.5.0->allure-pytest) (2.3.0)
# Requirement already satisfied: packaging>=22 in /home/ganesh-datta-padamata/prac/Python_practice/.venv/lib/python3.12/site-packages (from pytest>=4.5.0->allure-pytest) (26.0)
# Requirement already satisfied: pygments>=2.7.2 in /home/ganesh-datta-padamata/prac/Python_practice/.venv/lib/python3.12/site-packages (from pytest>=4.5.0->allure-pytest) (2.19.2)
# Downloading allure_pytest-2.15.3-py3-none-any.whl (12 kB)
# Downloading allure_python_commons-2.15.3-py3-none-any.whl (16 kB)
# Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
# Installing collected packages: attrs, allure-python-commons, allure-pytest
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [allure-pytest]
# Successfully installed allure-pytest-2.15.3 allure-python-commons-2.15.3 attrs-26.1.0
# Note: you may need to restart the kernel to use updated packages.
